# %%
# %pip install zoopt
# %pip install pandas
# %pip install -U scikit-learn
# %pip install seaborn
# %pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: zoopt in /home/idrone2/.local/lib/python3.11/site-packages (0.4.2)
# Requirement already satisfied: numpy in /home/idrone2/.local/lib/python3.11/site-packages (from zoopt) (1.26.4)
# Requirement already satisfied: matplotlib in /home/idrone2/.local/lib/python3.11/site-packages (from zoopt) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (24.1)
# Requirement already satisfied: pillow>=8 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib->zoopt) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/idrone2/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->zoopt) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/idrone2/.local/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /home/idrone2/.local/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/idrone2/.local/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/idrone2/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/idrone2/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/idrone2/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/idrone2/.local/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/idrone2/.local/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/idrone2/.local/lib/python3.11/site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/idrone2/.local/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/idrone2/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/idrone2/.local/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/idrone2/.local/lib/python3.11/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/idrone2/.local/lib/python3.11/site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/idrone2/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/idrone2/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/idrone2/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/idrone2/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/idrone2/.local/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: absl-py in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /home/idrone2/.local/lib/python3.11/site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/idrone2/.local/lib/python3.11/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/idrone2/.local/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/idrone2/.local/lib/python3.11/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/idrone2/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from zoopt import Dimension, Objective, Parameter, Opt

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, BatchNormalization, RandomFlip, RandomRotation
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import EfficientNetB3

# %%
print(tf.__version__)
# Out:
# 2.17.0

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS = 3
EPOCHS = 50
K = 10

# %%
def loading_data(dataset_path):
    filepaths = []
    labels = []

    folds = os.listdir(dataset_path)
    for fold in folds:
        foldpath = os.path.join(dataset_path, fold)
        filelist = os.listdir(foldpath)
        for file in filelist:
            fpath = os.path.join(foldpath, file)
            filepaths.append(fpath)
            labels.append(fold)

    Fseries = pd.Series(filepaths, name='filepath')
    Lseries = pd.Series(labels, name='labels')

    df = pd.concat([Fseries, Lseries], axis=1)
    return df

# %%
def change_label_name(df, column_name):
    index = {
        'lun_Opac': 'Lung_Opacity',
        'normal': 'Normal',
        'Viral_pneu': 'Viral_pneumonia',    
    }
    df[column_name] = df[column_name].replace(index)

# %%
dataset_path = "/home/idrone2/Desktop/Lung X-Ray Image"
df = loading_data(dataset_path)

image_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    seed=123,
    shuffle=True,
    image_size=(256, 256),  # Example size, replace with your actual IMAGE_SIZE
    batch_size=BATCH_SIZE  # Example size, replace with your actual BATCH_SIZE
)

change_label_name(df, 'labels')
df
# Out:
# Found 3475 files belonging to 3 classes.
#                                                filepath           labels
# 0     /home/idrone2/Desktop/Lung X-Ray Image/Normal/...           Normal
# 1     /home/idrone2/Desktop/Lung X-Ray Image/Normal/...           Normal
# 2     /home/idrone2/Desktop/Lung X-Ray Image/Normal/...           Normal
# 3     /home/idrone2/Desktop/Lung X-Ray Image/Normal/...           Normal
# 4     /home/idrone2/Desktop/Lung X-Ray Image/Normal/...           Normal
# ...                                                 ...              ...
# 3470  /home/idrone2/Desktop/Lung X-Ray Image/Viral P...  Viral Pneumonia
# 3471  /home/idrone2/Desktop/Lung X-Ray Image/Viral P...  Viral Pneumonia
# 3472  /home/idrone2/Desktop/Lung X-Ray Image/Viral P...  Viral Pneumonia
# 3473  /home/idrone2/Desktop/Lung X-Ray Image/Viral P...  Viral Pneumonia
# 3474  /home/idrone2/Desktop/Lung X-Ray Image/Viral P...  Viral Pneumonia
#
# [3475 rows x 2 columns]

# %%
class_names = image_dataset.class_names

# %%
data_balance = df.labels.value_counts()

def custom_autopct(pct):
    total = sum(data_balance)
    val = int(round(pct*total/100.0))
    return "{:.1f}%\n({:d})".format(pct, val)

colors = ['#20df00', '#8f5ddf', '#44ffdd', '#ddff66', '#ffde45', '#ee44ff', '#ffee44', '#ed445c']
plt.pie(data_balance, autopct=custom_autopct, labels=data_balance.index, colors=colors, textprops={'fontsize':6}, pctdistance=0.8, labeldistance=1.1)
plt.title("Dataset Balance")
plt.axis("equal")
plt.show()

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in image_dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(image_dataset)
len(train_ds)
len(val_ds)
len(test_ds)
# Out:
# 12

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    tf.keras.layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    tf.keras.layers.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=input_shape),  # Add InputLayer as the first layer
    resize_and_rescale,
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax'),
])

model.summary()
# Out:
# /home/idrone2/.local/lib/python3.11/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_10 (Sequential)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_36 (MaxPooling2D) │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_37 (MaxPooling2D) │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_38 (MaxPooling2D) │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_39 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_40 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_41 (MaxPooling2D) │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,747 (717.76 KB)
#  Trainable params: 183,747 (717.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723542779.784904    9094 service.cc:146] XLA service 0x7364ec003660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1723542779.784920    9094 service.cc:154]   StreamExecutor device (0): NVIDIA RTX A2000 12GB, Compute Capability 8.6
# 2024-08-13 15:22:59.806577: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-13 15:22:59.932240: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8902
#  3/87 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.3594 - loss: 1.0989
# I0000 00:00:1723542788.363918    9094 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 27s 190ms/step - accuracy: 0.4529 - loss: 1.0214 - val_accuracy: 0.7469 - val_loss: 0.6404
# Epoch 2/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.6982 - loss: 0.6882 - val_accuracy: 0.7500 - val_loss: 0.5861
# Epoch 3/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.7385 - loss: 0.6048 - val_accuracy: 0.8000 - val_loss: 0.5242
# Epoch 4/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.7808 - loss: 0.5388 - val_accuracy: 0.8062 - val_loss: 0.5372
# Epoch 5/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.7849 - loss: 0.5293 - val_accuracy: 0.8062 - val_loss: 0.4895
# Epoch 6/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.7954 - loss: 0.5141 - val_accuracy: 0.8062 - val_loss: 0.4778
# Epoch 7/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8039 - loss: 0.4714 - val_accuracy: 0.7437 - val_loss: 0.5569
# Epoch 8/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.7960 - loss: 0.4906 - val_accuracy: 0.8375 - val_loss: 0.4139
# Epoch 9/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8078 - loss: 0.4730 - val_accuracy: 0.8406 - val_loss: 0.3680
# Epoch 10/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8259 - loss: 0.4428 - val_accuracy: 0.8375 - val_loss: 0.4075
# Epoch 11/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8271 - loss: 0.4595 - val_accuracy: 0.8438 - val_loss: 0.3792
# Epoch 12/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8381 - loss: 0.4126 - val_accuracy: 0.8500 - val_loss: 0.4037
# Epoch 13/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8224 - loss: 0.4439 - val_accuracy: 0.8719 - val_loss: 0.3793
# Epoch 14/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8204 - loss: 0.4353 - val_accuracy: 0.8562 - val_loss: 0.3304
# Epoch 15/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8365 - loss: 0.4147 - val_accuracy: 0.8656 - val_loss: 0.3303
# Epoch 16/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8505 - loss: 0.3783 - val_accuracy: 0.8531 - val_loss: 0.3286
# Epoch 17/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8447 - loss: 0.3989 - val_accuracy: 0.8687 - val_loss: 0.3597
# Epoch 18/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8324 - loss: 0.4093 - val_accuracy: 0.8469 - val_loss: 0.3397
# Epoch 19/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.8365 - loss: 0.4052 - val_accuracy: 0.8687 - val_loss: 0.3099
# Epoch 20/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.